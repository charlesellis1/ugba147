# %% [markdown]
# # Data Visualization

# %% [markdown]
# **Write and execute R code in the code cells per the instructions.  The expected results are provided for you directly following the code cells.**

# %%
f = "setup.R"; for (i in 1:10) { if (file.exists(f)) break else f = paste0("../", f) }; source(f)
# Out:
# <p style="text-align:center; font-size:10px;">
# .................................................... start of document ....................................................
# </p>

# %% [markdown]
# ## Data

# %%
data = data.frame(name=c("A","B","C","D","E","F"),
                  x1=c(2.5, 2, 9, 6.5, 8, 4),
                  x2=c(7, 3.5, 1, 7, 2.5, 8.5),
                  x3=c(9, 10, 1, 2, 1.5, 9))
data
# Out:
#   name x1  x2  x3
# 1 A    2.5 7.0  9.0
# 2 B    2.0 3.5 10.0
# 3 C    9.0 1.0  1.0
# 4 D    6.5 7.0  2.0
# 5 E    8.0 2.5  1.5
# 6 F    4.0 8.5  9.0

# %% [markdown]
# ## Exercise 1
#
# Show scatterplots of x1 vs. x2, x1 vs. x3, and x2 vs. x3, presented side-by-side.  Label each point by its name.  Distinguish each scatterplot by point color.  Title each scatterplot with the correlation between the variables shown in that scatterplot.  Scale each scatterplot horizontally 0 to 11 and vertically 0 to 11.
#
# You may want to use these function(s):
# * ggplot()
# * ggtitle()
# * sprintf()
# * cor()
# * xlim()
# * ylim()
# * geom_point()
# * geom_text()
# * grid.arrange()

# %%
p1_cor = cor(data$x1, data$x2)
p2_cor = cor(data$x1, data$x3)
p3_cor = cor(data$x2, data$x3)

p1 = ggplot(data, aes(x=x1, y=x2)) + ggtitle(sprintf("correlation = %.2f", p1_cor)) +xlab("x1") +
ylab("x2") + xlim(0,11) + ylim(0,11) + geom_point() + geom_text(label=data$name)

p2 = ggplot(data, aes(x=x1, y=x3)) + ggtitle(sprintf("correlation = %.2f", p2_cor)) + xlab("x1") +
ylab("x3") + xlim(0,11) + ylim(0,11) + geom_point(color="red") + geom_text(label=data$name)

p3 = ggplot(data, aes(x=x2, y=x3)) + ggtitle(sprintf("correlation = %.2f", p3_cor)) + xlab("x2") + 
ylab("x3") + xlim(0,11) + ylim(0,11) + geom_point(color="green") + geom_text(label=data$name)

grid.arrange(p1, p2, p3, nrow=1)
# Out:
# plot without title

# %% [markdown]
# ## Exercise 2
#
# Show scatterplots of x1 vs. x2, x1 vs. x3, and x2 vs. x3, leveraging the ggscatmat function.
#
# You may want to use these function(s):
# * ggscatmat()

# %%
ggscatmat(data, columns=2:4)
# Out:
# plot without title

# %% [markdown]
# ## Exercise 3
#
# Show a lineplot of the numeric data, with x1 as the shared sequence control.  Show points on the lineplot corresponding to the observations.  Distinguish x2 vs. x3 by color.  Title as "Line".  Show a horizontal axis label, but not vertical axis label.  Include a legend.
#
# Show a pathplot of the numeric data.  Show points on the pathplot corresponding to the observations.  Distinguish x2 vs. x3 by color.  Title as "Path".  Show a horizontal axis label, but not vertical axis label.  Include a legend.
#
# Present the lineplot and pathplot side-by-side.
#
# You may want to use these function(s):
# * ggplot()
# * ggtitle()
# * ylab()
# * geom_point()
# * geom_line()
# * geom_path
# * scale_color_manual()
# * grid.arrange()

# %%
p_1 = ggplot(data) + ggtitle("Line") + xlab("x1") +
ylab("")+ geom_line(aes(x=x1, y=x2, color="x2")) + geom_point(aes(x=x1, y=x2, color="x2")) +
geom_line(aes(x=x1, y=x3, color="x3")) + geom_point(aes(x=x1, y=x3, color="x3"))

p_2 = ggplot(data) + ggtitle("Path") + xlab("x1") + ylab("") + geom_path(aes(x=x1, y=x2, color="x2")) +
geom_point(aes(x=x1, y=x2, color="x2")) + geom_path(aes(x=x1, y=x3, color="x3")) +
geom_point(aes(x=x1, y=x3, color="x3"))

grid.arrange(p_1, p_2, nrow=1)
# Out:
# plot without title

# %% [markdown]
# ## Exercise 4
#
# Show a set of histograms, one for each numeric variable.  Use 10 bins.  Scale horizontally 0 to 11 and vertically 0 to 3.  Distiguish x1 vs. x2 vs. x3 by color.
#
# Present the histograms side-by-side.
#
# You may want to use these function(s):
# * ggplot()
# * xlim()
# * ylim()
# * geom_histogram()
# * grid.arrange()

# %%
p__1 = ggplot(data) + xlim(0,11) + ylim(0,3) + geom_histogram(aes(x1), bins=10)
p__2 = ggplot(data) + xlim(0,11) + ylim(0,3) + geom_histogram(aes(x2), bins=10, color="red")
p__3 = ggplot(data) + xlim(0,11) + ylim(0,3) + geom_histogram(aes(x3), bins=10, color="green")

grid.arrange(p__1, p__2, p__3, nrow=1)
# Out:
# Warning message:
# “Removed 2 rows containing missing values (geom_bar).”
# Warning message:
# “Removed 2 rows containing missing values (geom_bar).”
# Warning message:
# “Removed 2 rows containing missing values (geom_bar).”
# plot without title

# %% [markdown]
# ## Exercise 5
#
# Show a scatterplot projection of x1 vs. x2 vs. x3.  Scale each axis 0 to 11.
#
# You may want to use these function(s):
# * open3d()
# * view3d()
# * plot3d()
# * grid3d()
# * rglwidget()

# %%
p = open3d()
view3d(-20, -4, zoom=0.65)
plot3d(data[,c("x1", "x2", "x3")], type="s", col=PALETTE[1:6], xlim=c(0,11), ylim=c(0,11), zlim=c(0,11))
grid3d(c("x", "y", "z"))
rglwidget(elementId="myplot", width=400, height=400, reuse=FALSE)
# Out:
# HTML widgets cannot be represented in plain text (need html)

# %% [markdown]
# <font size=1;>
# <p style="text-align: left;">
# Copyright (c) Berkeley Data Analytics Group, LLC
# <span style="float: right;">
# Document revised December 17, 2019
# </span>
# </p>
# </font>
